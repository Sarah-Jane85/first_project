# %%
pip install requests beautifulsoup4

# %%
from bs4 import BeautifulSoup
import pandas as pd
#upc urls don't work because it has ../../../ so need another librabry
from urllib.parse import urljoin
import requests

# %%
main_url = "https://assets.plasticbank.com/wp-content/uploads/2025/05/18212359/300DPI-Large-Size-PlasticBank-SustainabilityReport-2024.pdf" 
response = requests.get("https://assets.plasticbank.com/wp-content/uploads/2025/05/18212359/300DPI-Large-Size-PlasticBank-SustainabilityReport-2024.pdf")
response

# %%
# <embed type="application/x-google-chrome-pdf" src="chrome-extension://mhjfbmdgcfjbbpaeojofohoefgiehjai/a2b6ff2e-c497-4894-abf2-1235a93a2f4a" original-url="https://assets.plasticbank.com/wp-content/uploads/2025/05/18212359/300DPI-Large-Size-PlasticBank-SustainabilityReport-2024.pdf" background-color="4280821800" javascript="allow" full-frame="">
#<embed type="application/x-google-chrome-pdf" src="chrome-extension://mhjfbmdgcfjbbpaeojofohoefgiehjai/20345d3c-e875-4695-b225-7b34cfaaf119" original-url="https://assets.plasticbank.com/wp-content/uploads/2025/05/20203733/PlasticBank-SustainabilityReport-2023.pdf" background-color="4280821800" javascript="allow" full-frame="">
