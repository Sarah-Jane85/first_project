# %%
pip install requests beautifulsoup4

# %%
from bs4 import BeautifulSoup
import pandas as pd
#upc urls don't work because it has ../../../ so need another librabry
from urllib.parse import urljoin
import requests

# %%
main_url = "https://assets.plasticbank.com/wp-content/uploads/2025/05/18212359/300DPI-Large-Size-PlasticBank-SustainabilityReport-2024.pdf" 
response = requests.get("https://assets.plasticbank.com/wp-content/uploads/2025/05/18212359/300DPI-Large-Size-PlasticBank-SustainabilityReport-2024.pdf")
response
